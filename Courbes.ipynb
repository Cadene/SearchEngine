# %%
# Approche par Clustering
# Ranking de départ: Modele de langue ou modele vectoriel 3
# Les 50 documents les plus pertinents renvoyés sont reordonnées selon:
# ordre des clusters: par rang / par similarité du représentant a la query / par taille de cluster décroissante / par taille de cluster croissante
# ordre des documents par rang

# Approche gloutonne:
# Ranking de départ: Modele de langue ou modele vectoriel 3
# Les 50 documents les plus pertinents renvoyés sont reordonnées par Dissimilarité moyenne

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Modele de Langue

# %% [markdown]
# ### Ordre des clusters selon le meilleur rang dans le cluster

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.6871794871794873, 0.6846153846153846, 0.6397435897435898, 0.6307692307692309, 0.6333333333333334, 0.635897435897436, 0.6410256410256411, 0.6423076923076925, 0.644871794871795, 0.6282051282051283, 0.6205128205128206, 0.6243589743589744, 0.6217948717948718, 0.6333333333333333, 0.6333333333333332, 0.6269230769230768, 0.6179487179487179, 0.6115384615384617, 0.6089743589743589, 0.6102564102564103]
CrAt20 = [0.6005703636138419, 0.5930919322223669, 0.5660053312227225, 0.5714894606198954, 0.5704675356849271, 0.5805761468804947, 0.5981946394989874, 0.6199603134385743, 0.6204984628897674, 0.6153543316586796, 0.6151676825589869, 0.6053580477493521, 0.6086233010146055, 0.6251741414784894, 0.6158989561163476, 0.6189109602153081, 0.6104758767802245, 0.6094167507210986, 0.6101595264638743, 0.6087350250393728]
k = range(1,21)

baselinePRLangue = PrAt20[0]
baselineCRLangue = CrAt20[0]

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
plt.plot([1,21], [PrAt20[0],PrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Pr@20')
plt.title("Precision en Diversite par clustering")
plt.axis([1,20,.5,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
plt.plot([1,21], [CrAt20[0],CrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par clustering")
plt.axis([1,20,.5,.75])
# Out:
# [1, 20, 0.5, 0.75]

# %% [markdown]
# ### Ordre des clusters selon la similarité du representant

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.6871794871794873, 0.6846153846153846, 0.6410256410256411, 0.6307692307692309, 0.6320512820512821, 0.6333333333333335, 0.6410256410256411, 0.635897435897436, 0.6410256410256412, 0.6333333333333335, 0.6230769230769232, 0.621794871794872, 0.6115384615384616, 0.6230769230769233, 0.6141025641025641, 0.6166666666666667, 0.6153846153846155, 0.6115384615384616, 0.6064102564102564, 0.6102564102564103]
CrAt20 = [0.6005703636138419, 0.5930919322223669, 0.5696683348857261, 0.5714894606198954, 0.5755957408131323, 0.5891231554275033, 0.5919675332718811, 0.6015537200319809, 0.6069351743264789, 0.6116970790883836, 0.6117683041596086, 0.5965668389581433, 0.6081494994538474, 0.627854794159142, 0.6149166051339965, 0.6017399669573583, 0.5998168900342814, 0.6220030372204286, 0.609829301133649, 0.6087350250393728]
k = range(1,21)

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
plt.plot([1,21], [PrAt20[0],PrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Pr@20')
plt.title("Precision en Diversite par clustering")
plt.axis([1,20,.5,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
plt.plot([1,21], [CrAt20[0],CrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par clustering")
plt.axis([1,20,.5,.75])
# Out:
# [1, 20, 0.5, 0.75]

# %% [markdown]
# ### Ordre des clusters selon la taille des clusters (croissante: plus petit en premier)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.6871794871794873, 0.6846153846153846, 0.6384615384615386, 0.6294871794871796, 0.6320512820512821, 0.6358974358974361, 0.6346153846153847, 0.6333333333333334, 0.6384615384615386, 0.6333333333333334, 0.6269230769230771, 0.6166666666666667, 0.6076923076923075, 0.6102564102564103, 0.6025641025641024, 0.6102564102564103, 0.6064102564102564, 0.6102564102564103, 0.6076923076923075, 0.6102564102564103]
CrAt20 = [0.6005703636138419, 0.5930919322223669, 0.5660053312227225, 0.574053563183998, 0.5723906126080041, 0.579965646269994, 0.5887624050667529, 0.597233764625069, 0.6065631228674708, 0.6203153127066171, 0.6073988008770619, 0.5976816661599271, 0.5983668907581953, 0.6151508314551792, 0.6044252446426358, 0.5959494611668524, 0.5964887367061279, 0.6106264508438422, 0.6070709483752962, 0.6087350250393728]
k = range(1,21)

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
plt.plot([1,21], [PrAt20[0],PrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Pr@20')
plt.title("Precision en Diversite par clustering")
plt.axis([1,20,.5,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
plt.plot([1,21], [CrAt20[0],CrAt20[0]], label='baseline')
plt.legend(loc=4)
plt.xlabel("nb clusters")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par clustering")
plt.axis([1,20,.5,.75])
# Out:
# [1, 20, 0.5, 0.75]

# %% [markdown]
# ### Ordre des clusters selon la taille des clusters (decroissante: plus grand en premier)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.


# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.6512820512820513, 0.6474358974358975, 0.623076923076923, 0.5923076923076922, 0.5769230769230769, 0.5884615384615385, 0.5846153846153846, 0.582051282051282, 0.5743589743589744, 0.576923076923077, 0.5717948717948718, 0.5615384615384615, 0.5615384615384615, 0.5641025641025639, 0.5641025641025641, 0.5666666666666667, 0.5525641025641025, 0.5615384615384614, 0.5538461538461538, 0.5474358974358973]
CrAt20 = [0.5700656026742984, 0.5843783430739953, 0.5821672691237909, 0.5646211276646059, 0.5509459139893923, 0.5674361065665413, 0.5716128879172359, 0.5531489444532924, 0.5347735999909913, 0.5439673852717332, 0.5548648211691691, 0.5654061317104796, 0.5628420291463769, 0.571413811631203, 0.5605163757337671, 0.570888210018645, 0.5848064978499762, 0.588723876767355, 0.5970572101006885, 0.5919290049724832]
k = range(1,21)

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
plt.plot([1,21], [PrAt20[0],PrAt20[0]], label='baseline')
plt.legend(loc=1)
plt.xlabel("nb clusters")
plt.ylabel('Pr@20')
plt.title("Precision en par clustering")
plt.axis([1,20,.5,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
plt.plot([1,21], [CrAt20[0],CrAt20[0]], label='baseline')
plt.legend(loc=1)
plt.xlabel("nb clusters")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par clustering")
plt.axis([1,20,.5,.75])
# Out:
# [1, 20, 0.5, 0.75]

# %% [markdown]
# # Approche Gloutonne: Dissimilarite moyenne

# %% [markdown]
# ## Modele de Langue

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.46282051282051273, 0.4666666666666667, 0.4833333333333334, 0.5089743589743589, 0.5243589743589744, 0.5461538461538461, 0.5769230769230769, 0.5923076923076922, 0.6166666666666666, 0.6320512820512821, 0.6512820512820513]
CrAt20 = [0.6182553356466399, 0.6307627959801875, 0.645232987624292, 0.6502287165330645, 0.6387398028702377, 0.6315049684614902, 0.6179768299333518, 0.5863889733454951, 0.5695493315058533, 0.5684752043447695, 0.540930526800092]
k = np.array(range(11))
k = k/10.

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
#plt.plot([0,1], [PrAt20[10],PrAt20[10]], label='baseline')
plt.plot([0,1], [baselinePRLangue, baselinePRLangue], label='baseline')
plt.legend(loc=2)
plt.xlabel("alpha")
plt.ylabel('Pr@20')
plt.title("Precision en Diversite par approche gloutonne (Dissimilarite moyenne)")
plt.axis([0,1,.4,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
#plt.plot([0,1], [CrAt20[10],CrAt20[10]], label='baseline')
plt.plot([0,1], [baselineCRLangue,baselineCRLangue], label='baseline')
plt.legend(loc=2)
plt.xlabel("alpha")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par approche gloutonne (Dissimilarite moyenne)")
plt.axis([0,1,.4,.75])
# Out:
# [0, 1, 0.4, 0.75]

# %% [markdown]
# ## Modele Vectoriel 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

PrAt20 = [0.4243589743589743, 0.4269230769230769, 0.4346153846153847, 0.4435897435897436, 0.45641025641025645, 0.47051282051282034, 0.4897435897435896, 0.5166666666666666, 0.5525641025641025, 0.6102564102564104, 0.653846153846154]
CrAt20 = [0.5867973009277357, 0.5691638072072857, 0.5848173967739186, 0.5970320339885559, 0.6083930964365748, 0.6185318304883523, 0.6096534705230359, 0.5825052162008684, 0.5873732949819906, 0.5910522247478769, 0.5674462011418533]
k = np.array(range(11))
k = k/10.

plt.figure()
plt.plot(k,PrAt20, label='Model de diversite')
#plt.plot([0,1], [PrAt20[10],PrAt20[10]], label='baseline')
plt.plot([0,1], [baselinePRVect,baselinePRVect], label='baseline')

plt.legend(loc=2)
plt.xlabel("alpha")
plt.ylabel('Pr@20')
plt.title("Precision en Diversite par approche gloutonne (Dissimilarite moyenne)")
plt.axis([0,1,.4,.75])

plt.figure()
plt.plot(k,CrAt20, label='Model de diversite')
#plt.plot([0,1], [CrAt20[10],CrAt20[10]], label='baseline')
plt.plot([0,1], [baselineCRVect,baselineCRVect], label='baseline')
plt.legend(loc=2)
plt.xlabel("alpha")
plt.ylabel('Cr@20')
plt.title("Rappel en Diversite par approche gloutonne (Dissimilarite moyenne)")
plt.axis([0,1,.4,.75])
# Out:
# [0, 1, 0.4, 0.75]
